# %%
#Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo
import pandas as pd

from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://redplanetscience.com'
#Retrieve/visit URL
browser.visit(url)

# %%
#Set an HTML object
html = browser.html

#Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')

#Container class houses all news articles on this page
news = soup.find('div', class_ = 'container')

#Narrowing down, querying each individual article
articles = news.find_all(class_ = 'row')

# %%
#Examine the results and look for a ul with the class 'container'
result = soup.find('div', id = 'news', class_ = 'container')

#Retrieve each list item
articles = result.find_all(class_='row')
for query in result:
    print(query)
# Out:
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8612_Sol427-437_backcap_push_positioning-320x240.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">November 8, 2022</div>
# <div class="content_title">Mars InSight Lander to Push on Top of the 'Mole'</div>
# <div class="article_teaser_body">Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8511_PIA23279-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">November 7, 2022</div>
# <div class="content_title">Deadline Closing for Names to Fly on NASA's Next Mars Rover</div>
# <div class="article_teaser_body">You have until Sept. 30 to send your names to Mars aboard the Mars 2020 rover. </div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8735_collage-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">November 7, 2022</div>
# <div class="content_title">Celebrate Mars Reconnaissance Orbiter's Views From Above</div>
# <div class="article_teaser_body">Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8736_PIA24043-Rover-and-Helicopter-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">November 4, 2022</div>
# <div class="content_title">NASA's Ingenuity Mars Helicopter Recharges Its Batteries in Flight</div>
# <div class="article_teaser_body">Headed to the Red Planet with the Perseverance rover, the pioneering helicopter is powered up for the first time in interplanetary space as part of a systems check.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8561_MarCO-32x24.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">November 3, 2022</div>
# <div class="content_title">NASA's Briefcase-Size MarCO Satellite Picks Up Honors</div>
# <div class="article_teaser_body">The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week &amp; Space Technology.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8609_list_image.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">October 28, 2022</div>
# <div class="content_title">NASA's Mars Reconnaissance Orbiter Undergoes Memory Update</div>
# <div class="article_teaser_body">Other orbiters will continue relaying data from Mars surface missions for a two-week period.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8805_1-MOXIE-PIA24176-320.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">October 28, 2022</div>
# <div class="content_title">MOXIE Could Help Future Rockets Launch Off Mars</div>
# <div class="article_teaser_body">NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8504_insight20190822-226.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">October 19, 2022</div>
# <div class="content_title">NASA-JPL Names 'Rolling Stones Rock' on Mars</div>
# <div class="article_teaser_body">NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8726_PIA23898-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">October 19, 2022</div>
# <div class="content_title">8 Martian Postcards to Celebrate Curiosity's Landing Anniversary</div>
# <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8744_PIA22957-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">October 16, 2022</div>
# <div class="content_title">NASA Engineers Checking InSight's Weather Sensors</div>
# <div class="article_teaser_body">An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8611_PIA22111-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">October 15, 2022</div>
# <div class="content_title">NASA Adds Return Sample Scientists to Mars 2020 Leadership Team</div>
# <div class="article_teaser_body">The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8654_MAIN-IMAGE-PIA23881-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">October 14, 2022</div>
# <div class="content_title">How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus </div>
# <div class="article_teaser_body">Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8603_list_image.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">October 12, 2022</div>
# <div class="content_title">NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget</div>
# <div class="article_teaser_body">Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8573_PIA23499-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">October 11, 2022</div>
# <div class="content_title">NASA's Mars 2020 Rover Completes Its First Drive</div>
# <div class="article_teaser_body">In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.</div>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8699_helicopter-delivery-system-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">October 8, 2022</div>
# <div class="content_title">How NASA's Mars Helicopter Will Reach the Red Planet's Surface</div>
# <div class="article_teaser_body">The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.</div>
# </div>
# </div>
# </div>
# </div>

# %%
#https://stackoverflow.com/questions/8276113/what-is-the-best-approach-to-search-some-text-in-body-html
#Week 12, Day 2, Activity 08

articles = result.find_all(class_ = 'row')
title_list = []
article_preview_list = []

for entry in articles:
    try:
        #scrapes title of article from the "content_title" section.
        title_query = entry.find('div', class_ = 'content_title')
        #scrapes text since it is the only datatype in the body.
        title_body = title_query.text
        #appends to the title_list list.
        title_list.append(title_body)

        #repeats process for article text.
        article_query = entry.find('div', class_ = 'article_teaser_body')
        article_body = article_query.text   
        article_preview_list.append(article_body) 

        print(title_body)
        print(article_body)
        
        print("---")

    except:
        print("Scraping Error") 
        #only prints if there is an entry that doesn't follow this convention.

print("\n\n")
print("Boop. Scraping Complete")
# Out:
# Mars InSight Lander to Push on Top of the 'Mole'
# Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.
# ---
# Deadline Closing for Names to Fly on NASA's Next Mars Rover
# You have until Sept. 30 to send your names to Mars aboard the Mars 2020 rover.
# ---
# Celebrate Mars Reconnaissance Orbiter's Views From Above
# Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.
# ---
# NASA's Ingenuity Mars Helicopter Recharges Its Batteries in Flight
# Headed to the Red Planet with the Perseverance rover, the pioneering helicopter is powered up for the first time in interplanetary space as part of a systems check.
# ---
# NASA's Briefcase-Size MarCO Satellite Picks Up Honors
# The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.
# ---
# NASA's Mars Reconnaissance Orbiter Undergoes Memory Update
# Other orbiters will continue relaying data from Mars surface missions for a two-week period.
# ---
# MOXIE Could Help Future Rockets Launch Off Mars
# NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# ---
# NASA-JPL Names 'Rolling Stones Rock' on Mars
# NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# ---
# 8 Martian Postcards to Celebrate Curiosity's Landing Anniversary
# The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.
# ---
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# ---
# NASA Adds Return Sample Scientists to Mars 2020 Leadership Team
# The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.
# ---
# How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus
# Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# ---
# NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget
# Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return.
# ---
# NASA's Mars 2020 Rover Completes Its First Drive
# In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.
# ---
# How NASA's Mars Helicopter Will Reach the Red Planet's Surface
# The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.
# ---
#
#
#
# Boop. Scraping Complete

# %%
browser.quit()

# %%
#Store all the dictionaries in a Python list. Print the list in your notebook
#Week 12, Day 2, Activity 08
#https://stackoverflow.com/questions/21930705/zip-dictionary-of-lists-in-python
#creating list of two dictionaries: first dict is filled with titles, second dict is filled with article previews.

mars_list = [{'title': i, 'article':j} for i, j in zip(title_list, article_preview_list)]
print(mars_list)
# Out:
# [{'title': "Mars InSight Lander to Push on Top of the 'Mole'", 'article': 'Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.'}, {'title': "Deadline Closing for Names to Fly on NASA's Next Mars Rover", 'article': 'You have until Sept. 30 to send your names to Mars aboard the Mars 2020 rover. '}, {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'article': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}, {'title': "NASA's Ingenuity Mars Helicopter Recharges Its Batteries in Flight", 'article': 'Headed to the Red Planet with the Perseverance rover, the pioneering helicopter is powered up for the first time in interplanetary space as part of a systems check.'}, {'title': "NASA's Briefcase-Size MarCO Satellite Picks Up Honors", 'article': 'The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.'}, {'title': "NASA's Mars Reconnaissance Orbiter Undergoes Memory Update", 'article': 'Other orbiters will continue relaying data from Mars surface missions for a two-week period.'}, {'title': 'MOXIE Could Help Future Rockets Launch Off Mars', 'article': "NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel."}, {'title': "NASA-JPL Names 'Rolling Stones Rock' on Mars", 'article': "NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert."}, {'title': "8 Martian Postcards to Celebrate Curiosity's Landing Anniversary", 'article': 'The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.'}, {'title': "NASA Engineers Checking InSight's Weather Sensors", 'article': 'An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.'}, {'title': 'NASA Adds Return Sample Scientists to Mars 2020 Leadership Team', 'article': 'The leadership council for Mars 2020 science added two new members who represent the interests of scientists destined to handle and study the first samples from Red Planet.'}, {'title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ", 'article': 'Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.'}, {'title': 'NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget', 'article': "Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return."}, {'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'article': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}, {'title': "How NASA's Mars Helicopter Will Reach the Red Planet's Surface", 'article': 'The small craft will seek to prove that powered, controlled flight is possible on another planet. But just getting it onto the surface of Mars will take a whole lot of ingenuity.'}]
